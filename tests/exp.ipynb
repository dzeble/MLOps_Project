# %%
import pandas as pd
import sys
sys.path.append('../')
from src.utils.functions import read_dataframe

# %%
test_df = read_dataframe("./wine_data/train_wine_data.csv")
actual_df = pd.read_csv("./wine_data/train_wine_data.csv")

# %%
actual_df
# Out:
#         type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# 0      white            7.4             0.170         0.29             1.4  \
# 1      white            5.3             0.310         0.38            10.5
# 2      white            4.7             0.145         0.29             1.0
# 3      white            6.9             0.260         0.29             4.2
# 4      white            6.4             0.450         0.07             1.1
# ...      ...            ...               ...          ...             ...
# 32480  white            5.0             0.255         0.22             2.7
# 32481  white            6.6             0.360         0.52            11.3
# 32482  white            6.3             0.200         0.24             1.7
# 32483  white            6.2             0.200         0.33             5.4
# 32484  white            8.1             0.280         0.46            15.4
#
# ...

# %%
test_df
# Out:
#        type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# 0         1            7.4             0.170         0.29             1.4  \
# 1         1            5.3             0.310         0.38            10.5
# 2         1            4.7             0.145         0.29             1.0
# 3         1            6.9             0.260         0.29             4.2
# 4         1            6.4             0.450         0.07             1.1
# ...     ...            ...               ...          ...             ...
# 32480     1            5.0             0.255         0.22             2.7
# 32481     1            6.6             0.360         0.52            11.3
# 32482     1            6.3             0.200         0.24             1.7
# 32483     1            6.2             0.200         0.33             5.4
# 32484     1            8.1             0.280         0.46            15.4
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH
# ...

# %%
print(len(test_df.columns))
# Out:
# 13

# %%
import mlflow

runs = mlflow.search_runs()

# Convert DataFrame to list of Run objects
run_objs = runs[["run_id", "artifact_uri"]].to_dict(orient="records")  

# Access run by index 
run = mlflow.get_run(run_objs[1]["run_id"])

print(run.data.tags)
# Out:
# {'developer': 'Sven', 'mlflow.log-model.history': '[{"run_id": "8de9ef331ed84ddf95c139dd26cd6cd4", "artifact_path": "model", "utc_time_created": "2024-02-01 16:01:35.091105", "flavors": {"python_function": {"model_path": "model.pkl", "predict_fn": "predict", "loader_module": "mlflow.sklearn", "python_version": "3.9.18", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "sklearn": {"pickled_model": "model.pkl", "sklearn_version": "1.2.2", "serialization_format": "cloudpickle", "code": null}}, "model_uuid": "f73944ce5fed458daa8cb8f1bac4f723", "mlflow_version": "2.3.1"}]', 'mlflow.runName': 'exultant-sponge-831', 'mlflow.source.git.commit': '997731b0c6faa806c167437bc31c27b184f20e06', 'mlflow.source.name': 'testTraining.py', 'mlflow.source.type': 'LOCAL', 'mlflow.user': 'sven', 'model': 'ExtraTreesClassifier'}

# %%
print(run.data.tags['developer'])
# Out:
# Sven

# %%
run = mlflow.get_run(mlflow.active_run().info.run_id)
print(run)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 run = mlflow.get_run(mlflow.active_run().info.run_id)
#       2 print(run)
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
with mlflow.start_run():
    run = mlflow.get_run(mlflow.active_run().info.run_id)
    print(run)
# Out:
# <Run: data=<RunData: metrics={}, params={}, tags={'mlflow.runName': 'melodic-cat-435',
#  'mlflow.source.name': '/home/sven/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'sven'}>, info=<RunInfo: artifact_uri='file:///mnt/c/Users/Dev/desktop/mlops_project/tests/mlruns/0/059b7a51f4fb4749a565323c6428f451/artifacts', end_time=None, experiment_id='0', lifecycle_stage='active', run_id='059b7a51f4fb4749a565323c6428f451', run_name='melodic-cat-435', run_uuid='059b7a51f4fb4749a565323c6428f451', start_time=1706806441659, status='RUNNING', user_id='sven'>>

# %%
print(run.data.tags)
# Out:
# {'mlflow.runName': 'melodic-cat-435', 'mlflow.source.name': '/home/sven/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel_launcher.py', 'mlflow.source.type': 'LOCAL', 'mlflow.user': 'sven'}

# %%
my_df = pd.read_csv('/mnt/c/Users/Dev/desktop/mlops_project/tests/wine_data/test_wine_data.csv')
my_df
# Out:
#        type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar
# 0     white            7.0             0.270         0.36            20.7  \
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH
# ...
