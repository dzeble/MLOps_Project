# %%
#imports for data exploration and analysis
import pandas as pd
import numpy as np
#imports for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
#importing models
from sklearn.ensemble import RandomForestRegressor, ExtraTreesClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import SVR

from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score


from sklearn.preprocessing import OneHotEncoder

import pickle

from urllib.parse import urlparse

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("wine-track")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 import mlflow
#       3 mlflow.set_tracking_uri("sqlite:///mlflow.db")
#       4 mlflow.set_experiment("wine-track")
#
# File c:\Python310\lib\site-packages\mlflow\__init__.py:44
#      41 warnings.filterwarnings("ignore", message="numpy.dtype size changed")
#      42 warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# ---> 44 from mlflow import (
#      45     artifacts,  # noqa: F401
#      46     client,  # noqa: F401
#      47     data,  # noqa: F401
#      48     exceptions,  # noqa: F401
#      49     models,  # noqa: F401
#      50     projects,  # noqa: F401
#      51     tracking,  # noqa: F401
#      52 )
#      54 # Lazily load mlflow flavors to avoid excessive dependencies.
#      55 catboost = LazyLoader("mlflow.catboost", globals(), "mlflow.catboost")
#
# File c:\Python310\lib\site-packages\mlflow\data\__init__.py:4
#       1 import sys
#       2 from typing import Union
# ----> 4 from mlflow.data import dataset_registry
#       5 from mlflow.data import sources as mlflow_data_sources
#       6 from mlflow.data.dataset import Dataset
#
# File c:\Python310\lib\site-packages\mlflow\data\dataset_registry.py:132
#     130 # use contextlib suppress to ignore import errors
#     131 with suppress(ImportError):
# --> 132     from mlflow.data.pandas_dataset import from_pandas
#     134     _dataset_registry.register_constructor(from_pandas)
#     135 with suppress(ImportError):
#
# File c:\Python310\lib\site-packages\mlflow\data\pandas_dataset.py:11
#       9 from mlflow.data.dataset_source import DatasetSource
#      10 from mlflow.data.digest_utils import compute_pandas_digest
# ---> 11 from mlflow.data.pyfunc_dataset_mixin import PyFuncConvertibleDatasetMixin, PyFuncInputsOutputs
#      12 from mlflow.exceptions import MlflowException
#      13 from mlflow.models.evaluation.base import EvaluationDataset
#
# File c:\Python310\lib\site-packages\mlflow\data\pyfunc_dataset_mixin.py:6
#       3 from typing import List
#       5 from mlflow.models.evaluation.base import EvaluationDataset
# ----> 6 from mlflow.models.utils import PyFuncInput, PyFuncOutput
#       9 @dataclass
#      10 class PyFuncInputsOutputs:
#      11     inputs: List[PyFuncInput]
#
# File c:\Python310\lib\site-packages\mlflow\models\__init__.py:44
#      34 from mlflow.models.evaluation import (
#      35     EvaluationArtifact,
#      36     EvaluationMetric,
#    (...)
#      41     make_metric,
#      42 )
#      43 from mlflow.models.flavor_backend import FlavorBackend
# ---> 44 from mlflow.models.flavor_backend_registry import get_flavor_backend
#      45 from mlflow.models.model import Model, get_model_info
#      46 from mlflow.utils import env_manager as _EnvManager
#
# File c:\Python310\lib\site-packages\mlflow\models\flavor_backend_registry.py:11
#       1 """
#       2 Registry of supported flavor backends. Contains a mapping of flavors to flavor backends. This
#       3 mapping is used to select suitable flavor when deploying generic MLflow models.
#    (...)
#       7 Not all flavors have a flavor backend.
#       8 """
#       9 import logging
# ---> 11 from mlflow.models.model import MLMODEL_FILE_NAME, Model
#      12 from mlflow.store.artifact.models_artifact_repo import ModelsArtifactRepository
#      13 from mlflow.tracking.artifact_utils import _download_artifact_from_uri
#
# File c:\Python310\lib\site-packages\mlflow\models\model.py:250
#     207         """
#     208         User defined metadata added to the model.
#     209
#    (...)
#     245             assert model_info.metadata["metadata_key"] == "metadata_value"
#     246         """
#     247         return self._metadata
# --> 250 class Model:
#     251     """
#     252     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     253     new Model flavors.
#     254     """
#     256     def __init__(
#     257         self,
#     258         artifact_path=None,
#    (...)
#     269     ):
#     270         # store model id instead of run_id and path to avoid confusion when model gets exported
#
# File c:\Python310\lib\site-packages\mlflow\models\model.py:265, in Model()
#     250 class Model:
#     251     """
#     252     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     253     new Model flavors.
#     254     """
#     256     def __init__(
#     257         self,
#     258         artifact_path=None,
#     259         run_id=None,
#     260         utc_time_created=None,
#     261         flavors=None,
#     262         signature=None,  # ModelSignature
#     263         saved_input_example_info: Optional[Dict[str, Any]] = None,
#     264         model_uuid: Union[str, Callable, None] = lambda: uuid.uuid4().hex,
# --> 265         mlflow_version: Union[str, None] = mlflow.version.VERSION,
#     266         metadata: Optional[Dict[str, Any]] = None,
#     267         model_size_bytes: Optional[int] = None,
#     268         **kwargs,
#     269     ):
#     270         # store model id instead of run_id and path to avoid confusion when model gets exported
#     271         if run_id:
#     272             self.run_id = run_id
#
# AttributeError: partially initialized module 'mlflow' has no attribute 'version' (most likely due to a circular import)

# %%
#reading the data with a function to avoid too much repetition
def read_dafaframe(filename):
    df = pd.read_csv(filename)

    encoder = OneHotEncoder(sparse=False)

    encoded_types = encoder.fit_transform(df['type'].values.reshape(-1, 1))

    label= ['red','white']
    wine_types = pd.DataFrame(encoded_types, columns= label)

    df['red_wine'] = wine_types['red']

    for col, value in df.items():
        if col != 'type':
            df[col] = df[col].fillna(df[col].mean())
        

    return df

# %%
train_df = read_dafaframe('./wine_data/train_wine_data.csv')
validation_df = read_dafaframe('./wine_data/test_wine_data.csv')

# %%
trained_dict =  train_df.drop(columns=['type','quality'])
val_dict =  validation_df.drop(columns=['type','quality'])

# %%
X_train = trained_dict
X_val = val_dict

# %%
target = 'quality'
y_train = train_df[target].values

y_val = validation_df[target].values

# %%
rfc = RandomForestClassifier(n_estimators=100)

rfc.fit(X_train, y_train)
y_pred_rfc = rfc.predict(X_val)

rmse = mean_squared_error(y_val,y_pred_rfc,squared=False)
accuracy = r2_score(y_val, y_pred_rfc)

print('RandomForestClassifier')
print(f'RMSE: {rmse}')
print(f'Accuracy: {accuracy}')
# Out:
# RandomForestClassifier
# RMSE: 0.06681016826772575
# Accuracy: 0.9941457731172564

# %%
etc = ExtraTreesClassifier(n_estimators=100)

etc.fit(X_train, y_train)
y_pred_etc = etc.predict(X_val)

rmse = mean_squared_error(y_val,y_pred_etc,squared=False)
accuracy = r2_score(y_val,y_pred_etc)

print('ExtraTreesClassifier')
print (f'RMSE: ',{rmse})
print(f'Accuracy: ',{accuracy})
# Out:
# ExtraTreesClassifier
# RMSE:  {0.06446521696900595}
# Accuracy:  {0.9945495129022732}

# %%
with open('models/etc.bin','wb') as f_out:
    pickle.dump((etc),f_out)

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","Sven")
    mlflow.log_param("train-data-path", "../wine_data/train_wine_data.csv")
    mlflow.log_param("valid-data-path", "../wine_data/test_wine_data.csv")

    n_estimators = 100
    mlflow.log_param('n_estimators',n_estimators)

    etc = ExtraTreesClassifier(n_estimators=n_estimators)
    
    etc.fit(X_train, y_train)
    y_pred_etc = etc.predict(X_val)

    rmse = mean_squared_error(y_val,y_pred_etc,squared=False)
    accuracy = r2_score(y_val,y_pred_etc)

    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("accuracy", accuracy)

# %%
import xgboost as xgb

from hyperopt import  fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 train = xgb.DMatrix(X_train, label=y_train)
#       2 valid = xgb.DMatrix(X_val, label=y_val)
#
# NameError: name 'X_train' is not defined

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        accuracy = r2_score(y_val,y_pred)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("accuracy", accuracy)

    return {'loss': rmse, 'accuracy':accuracy, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# job exception: name 'mlflow' is not defined
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In [3], line 2, in objective(params)
#       1 def objective(params):
# ----> 2     with mlflow.start_run():
#       3         mlflow.set_tag("model", "xgboost")
#       4         mlflow.log_params(params)
#
# NameError: name 'mlflow' is not defined

# %%
params ={
'learning_rate':	0.20830135987468326,
'max_depth':	10,
'min_child_weight':	9.327167178212004,
'objective':	'reg:linear',
'reg_alpha':	0.012980494736910292,
'reg_lambda':	0.0559890740248936,
'seed':	42
}

mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=1000,
    evals=[(valid, 'validation')],
    early_stopping_rounds=50
)


mlflow.xgboost.log_model(booster, artifact_path="models")
# Out:
# 2024/01/18 17:40:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8b4f4fbb54514bdebea181d89612aa4c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [17:40:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:4.28088
# [1]	validation-rmse:3.40449
# [2]	validation-rmse:2.71342
# [3]	validation-rmse:2.16790
# [4]	validation-rmse:1.73820
# [5]	validation-rmse:1.39954
# [6]	validation-rmse:1.13357
# [7]	validation-rmse:0.92946
# [8]	validation-rmse:0.76743
# [9]	validation-rmse:0.64408
# [10]	validation-rmse:0.54921
# [11]	validation-rmse:0.47781
# [12]	validation-rmse:0.42098
# [13]	validation-rmse:0.38219
# [14]	validation-rmse:0.35126
# [15]	validation-rmse:0.32875
# [16]	validation-rmse:0.31109
# [17]	validation-rmse:0.29743
# [18]	validation-rmse:0.28597
# [19]	validation-rmse:0.27277
# [20]	validation-rmse:0.26657
# [21]	validation-rmse:0.25887
# [22]	validation-rmse:0.25434
# [23]	validation-rmse:0.25194
# [24]	validation-rmse:0.24965
# [25]	validation-rmse:0.24844
# [26]	validation-rmse:0.24239
# [27]	validation-rmse:0.24083
# [28]	validation-rmse:0.23946
# [29]	validation-rmse:0.23356
# [30]	validation-rmse:0.22863
# [31]	validation-rmse:0.22292
# [32]	validation-rmse:0.21590
# [33]	validation-rmse:0.21080
# [34]	validation-rmse:0.20830
# [35]	validation-rmse:0.20547
# [36]	validation-rmse:0.20339
# [37]	validation-rmse:0.20314
# [38]	validation-rmse:0.19903
# [39]	validation-rmse:0.19714
# [40]	validation-rmse:0.19498
# [41]	validation-rmse:0.19191
# [42]	validation-rmse:0.18892
# [43]	validation-rmse:0.18376
# [44]	validation-rmse:0.18230
# [45]	validation-rmse:0.17660
# [46]	validation-rmse:0.17460
# [47]	validation-rmse:0.17137
# [48]	validation-rmse:0.16892
# [49]	validation-rmse:0.16875
# [50]	validation-rmse:0.16454
# [51]	validation-rmse:0.16367
# [52]	validation-rmse:0.15923
# [53]	validation-rmse:0.15683
# [54]	validation-rmse:0.15643
# [55]	validation-rmse:0.15445
# [56]	validation-rmse:0.15051
# [57]	validation-rmse:0.14904
# [58]	validation-rmse:0.14626
# [59]	validation-rmse:0.14427
# [60]	validation-rmse:0.14195
# [61]	validation-rmse:0.14157
# [62]	validation-rmse:0.13954
# [63]	validation-rmse:0.13630
# [64]	validation-rmse:0.13510
# [65]	validation-rmse:0.13293
# [66]	validation-rmse:0.13016
# [67]	validation-rmse:0.12938
# [68]	validation-rmse:0.12885
# [69]	validation-rmse:0.12615
# [70]	validation-rmse:0.12473
# [71]	validation-rmse:0.12327
# [72]	validation-rmse:0.12031
# [73]	validation-rmse:0.11917
# [74]	validation-rmse:0.11868
# [75]	validation-rmse:0.11653
# [76]	validation-rmse:0.11552
# [77]	validation-rmse:0.11412
# [78]	validation-rmse:0.11355
# [79]	validation-rmse:0.11200
# [80]	validation-rmse:0.11070
# [81]	validation-rmse:0.11008
# [82]	validation-rmse:0.10978
# [83]	validation-rmse:0.10960
# [84]	validation-rmse:0.10944
# [85]	validation-rmse:0.10825
# [86]	validation-rmse:0.10730
# [87]	validation-rmse:0.10711
# [88]	validation-rmse:0.10584
# [89]	validation-rmse:0.10535
# [90]	validation-rmse:0.10464
# [91]	validation-rmse:0.10451
# [92]	validation-rmse:0.10353
# [93]	validation-rmse:0.10200
# [94]	validation-rmse:0.10155
# [95]	validation-rmse:0.10144
# [96]	validation-rmse:0.10046
# [97]	validation-rmse:0.10017
# [98]	validation-rmse:0.09947
# [99]	validation-rmse:0.09887
# [100]	validation-rmse:0.09847
# [101]	validation-rmse:0.09768
# [102]	validation-rmse:0.09700
# [103]	validation-rmse:0.09654
# [104]	validation-rmse:0.09621
# [105]	validation-rmse:0.09425
# [106]	validation-rmse:0.09344
# [107]	validation-rmse:0.09286
# [108]	validation-rmse:0.09226
# [109]	validation-rmse:0.09148
# [110]	validation-rmse:0.09101
# [111]	validation-rmse:0.09065
# [112]	validation-rmse:0.09034
# [113]	validation-rmse:0.09028
# [114]	validation-rmse:0.09024
# [115]	validation-rmse:0.08956
# [116]	validation-rmse:0.08934
# [117]	validation-rmse:0.08880
# [118]	validation-rmse:0.08802
# [119]	validation-rmse:0.08795
# [120]	validation-rmse:0.08659
# [121]	validation-rmse:0.08634
# [122]	validation-rmse:0.08617
# [123]	validation-rmse:0.08606
# [124]	validation-rmse:0.08600
# [125]	validation-rmse:0.08551
# [126]	validation-rmse:0.08531
# [127]	validation-rmse:0.08445
# [128]	validation-rmse:0.08398
# [129]	validation-rmse:0.08325
# [130]	validation-rmse:0.08283
# [131]	validation-rmse:0.08238
# [132]	validation-rmse:0.08151
# [133]	validation-rmse:0.08066
# [134]	validation-rmse:0.07998
# [135]	validation-rmse:0.07934
# [136]	validation-rmse:0.07930
# [137]	validation-rmse:0.07886
# [138]	validation-rmse:0.07837
# [139]	validation-rmse:0.07816
# [140]	validation-rmse:0.07789
# [141]	validation-rmse:0.07745
# [142]	validation-rmse:0.07731
# [143]	validation-rmse:0.07709
# [144]	validation-rmse:0.07680
# [145]	validation-rmse:0.07649
# [146]	validation-rmse:0.07616
# [147]	validation-rmse:0.07599
# [148]	validation-rmse:0.07578
# [149]	validation-rmse:0.07551
# [150]	validation-rmse:0.07509
# [151]	validation-rmse:0.07506
# [152]	validation-rmse:0.07480
# [153]	validation-rmse:0.07474
# [154]	validation-rmse:0.07450
# [155]	validation-rmse:0.07428
# [156]	validation-rmse:0.07400
# [157]	validation-rmse:0.07374
# [158]	validation-rmse:0.07366
# [159]	validation-rmse:0.07348
# [160]	validation-rmse:0.07341
# [161]	validation-rmse:0.07314
# [162]	validation-rmse:0.07306
# [163]	validation-rmse:0.07277
# [164]	validation-rmse:0.07265
# [165]	validation-rmse:0.07228
# [166]	validation-rmse:0.07201
# [167]	validation-rmse:0.07196
# [168]	validation-rmse:0.07191
# [169]	validation-rmse:0.07178
# [170]	validation-rmse:0.07158
# [171]	validation-rmse:0.07135
# [172]	validation-rmse:0.07102
# [173]	validation-rmse:0.07083
# [174]	validation-rmse:0.07075
# [175]	validation-rmse:0.07068
# [176]	validation-rmse:0.07057
# [177]	validation-rmse:0.07051
# [178]	validation-rmse:0.07035
# [179]	validation-rmse:0.07026
# [180]	validation-rmse:0.07009
# [181]	validation-rmse:0.06973
# [182]	validation-rmse:0.06971
# [183]	validation-rmse:0.06964
# [184]	validation-rmse:0.06942
# [185]	validation-rmse:0.06926
# [186]	validation-rmse:0.06921
# [187]	validation-rmse:0.06904
# [188]	validation-rmse:0.06893
# [189]	validation-rmse:0.06877
# [190]	validation-rmse:0.06868
# [191]	validation-rmse:0.06862
# [192]	validation-rmse:0.06851
# [193]	validation-rmse:0.06845
# [194]	validation-rmse:0.06843
# [195]	validation-rmse:0.06831
# [196]	validation-rmse:0.06812
# [197]	validation-rmse:0.06803
# [198]	validation-rmse:0.06798
# [199]	validation-rmse:0.06770
# [200]	validation-rmse:0.06753
# [201]	validation-rmse:0.06744
# [202]	validation-rmse:0.06741
# [203]	validation-rmse:0.06731
# [204]	validation-rmse:0.06720
# [205]	validation-rmse:0.06712
# [206]	validation-rmse:0.06708
# [207]	validation-rmse:0.06700
# [208]	validation-rmse:0.06692
# [209]	validation-rmse:0.06690
# [210]	validation-rmse:0.06687
# [211]	validation-rmse:0.06684
# [212]	validation-rmse:0.06681
# [213]	validation-rmse:0.06678
# [214]	validation-rmse:0.06663
# [215]	validation-rmse:0.06655
# [216]	validation-rmse:0.06647
# [217]	validation-rmse:0.06635
# [218]	validation-rmse:0.06622
# [219]	validation-rmse:0.06618
# [220]	validation-rmse:0.06613
# [221]	validation-rmse:0.06597
# [222]	validation-rmse:0.06592
# [223]	validation-rmse:0.06585
# [224]	validation-rmse:0.06578
# [225]	validation-rmse:0.06569
# [226]	validation-rmse:0.06566
# [227]	validation-rmse:0.06564
# [228]	validation-rmse:0.06561
# [229]	validation-rmse:0.06560
# [230]	validation-rmse:0.06559
# [231]	validation-rmse:0.06557
# [232]	validation-rmse:0.06556
# [233]	validation-rmse:0.06551
# [234]	validation-rmse:0.06547
# [235]	validation-rmse:0.06544
# [236]	validation-rmse:0.06538
# [237]	validation-rmse:0.06531
# [238]	validation-rmse:0.06527
# [239]	validation-rmse:0.06523
# [240]	validation-rmse:0.06515
# [241]	validation-rmse:0.06512
# [242]	validation-rmse:0.06506
# [243]	validation-rmse:0.06500
# [244]	validation-rmse:0.06494
# [245]	validation-rmse:0.06492
# [246]	validation-rmse:0.06484
# [247]	validation-rmse:0.06482
# [248]	validation-rmse:0.06481
# [249]	validation-rmse:0.06479
# [250]	validation-rmse:0.06477
# [251]	validation-rmse:0.06472
# [252]	validation-rmse:0.06466
# [253]	validation-rmse:0.06463
# [254]	validation-rmse:0.06460
# [255]	validation-rmse:0.06458
# [256]	validation-rmse:0.06455
# [257]	validation-rmse:0.06451
# [258]	validation-rmse:0.06450
# [259]	validation-rmse:0.06446
# [260]	validation-rmse:0.06440
# [261]	validation-rmse:0.06439
# [262]	validation-rmse:0.06437
# [263]	validation-rmse:0.06434
# [264]	validation-rmse:0.06430
# [265]	validation-rmse:0.06427
# [266]	validation-rmse:0.06426
# [267]	validation-rmse:0.06420
# [268]	validation-rmse:0.06419
# [269]	validation-rmse:0.06414
# [270]	validation-rmse:0.06412
# [271]	validation-rmse:0.06412
# [272]	validation-rmse:0.06410
# [273]	validation-rmse:0.06405
# [274]	validation-rmse:0.06400
# [275]	validation-rmse:0.06397
# [276]	validation-rmse:0.06395
# [277]	validation-rmse:0.06392
# [278]	validation-rmse:0.06389
# [279]	validation-rmse:0.06385
# [280]	validation-rmse:0.06378
# [281]	validation-rmse:0.06376
# [282]	validation-rmse:0.06375
# [283]	validation-rmse:0.06370
# [284]	validation-rmse:0.06368
# [285]	validation-rmse:0.06362
# [286]	validation-rmse:0.06356
# [287]	validation-rmse:0.06354
# [288]	validation-rmse:0.06351
# [289]	validation-rmse:0.06349
# [290]	validation-rmse:0.06349
# [291]	validation-rmse:0.06344
# [292]	validation-rmse:0.06342
# [293]	validation-rmse:0.06340
# [294]	validation-rmse:0.06340
# [295]	validation-rmse:0.06338
# [296]	validation-rmse:0.06335
# [297]	validation-rmse:0.06335
# [298]	validation-rmse:0.06333
# [299]	validation-rmse:0.06332
# [300]	validation-rmse:0.06330
# [301]	validation-rmse:0.06328
# [302]	validation-rmse:0.06325
# [303]	validation-rmse:0.06322
# [304]	validation-rmse:0.06321
# [305]	validation-rmse:0.06320
# [306]	validation-rmse:0.06317
# [307]	validation-rmse:0.06317
# [308]	validation-rmse:0.06314
# [309]	validation-rmse:0.06312
# [310]	validation-rmse:0.06311
# [311]	validation-rmse:0.06309
# [312]	validation-rmse:0.06307
# [313]	validation-rmse:0.06305
# [314]	validation-rmse:0.06303
# [315]	validation-rmse:0.06300
# [316]	validation-rmse:0.06299
# [317]	validation-rmse:0.06298
# [318]	validation-rmse:0.06295
# [319]	validation-rmse:0.06293
# [320]	validation-rmse:0.06291
# [321]	validation-rmse:0.06290
# [322]	validation-rmse:0.06289
# [323]	validation-rmse:0.06288
# [324]	validation-rmse:0.06286
# [325]	validation-rmse:0.06285
# [326]	validation-rmse:0.06285
# [327]	validation-rmse:0.06283
# [328]	validation-rmse:0.06282
# [329]	validation-rmse:0.06281
# [330]	validation-rmse:0.06279
# [331]	validation-rmse:0.06277
# [332]	validation-rmse:0.06276
# [333]	validation-rmse:0.06274
# [334]	validation-rmse:0.06274
# [335]	validation-rmse:0.06272
# [336]	validation-rmse:0.06272
# [337]	validation-rmse:0.06269
# [338]	validation-rmse:0.06269
# [339]	validation-rmse:0.06268
# [340]	validation-rmse:0.06267
# [341]	validation-rmse:0.06265
# [342]	validation-rmse:0.06263
# [343]	validation-rmse:0.06262
# [344]	validation-rmse:0.06261
# [345]	validation-rmse:0.06260
# [346]	validation-rmse:0.06259
# [347]	validation-rmse:0.06257
# [348]	validation-rmse:0.06257
# [349]	validation-rmse:0.06256
# [350]	validation-rmse:0.06255
# [351]	validation-rmse:0.06253
# [352]	validation-rmse:0.06253
# [353]	validation-rmse:0.06252
# [354]	validation-rmse:0.06251
# [355]	validation-rmse:0.06250
# [356]	validation-rmse:0.06250
# [357]	validation-rmse:0.06249
# [358]	validation-rmse:0.06248
# [359]	validation-rmse:0.06247
# [360]	validation-rmse:0.06246
# [361]	validation-rmse:0.06246
# [362]	validation-rmse:0.06246
# [363]	validation-rmse:0.06245
# [364]	validation-rmse:0.06245
# [365]	validation-rmse:0.06245
# [366]	validation-rmse:0.06244
# [367]	validation-rmse:0.06243
# [368]	validation-rmse:0.06241
# [369]	validation-rmse:0.06241
# [370]	validation-rmse:0.06241
# [371]	validation-rmse:0.06240
# [372]	validation-rmse:0.06240
# [373]	validation-rmse:0.06240
# [374]	validation-rmse:0.06239
# [375]	validation-rmse:0.06239
# [376]	validation-rmse:0.06238
# [377]	validation-rmse:0.06237
# [378]	validation-rmse:0.06237
# [379]	validation-rmse:0.06237
# [380]	validation-rmse:0.06236
# [381]	validation-rmse:0.06236
# [382]	validation-rmse:0.06235
# [383]	validation-rmse:0.06235
# [384]	validation-rmse:0.06234
# [385]	validation-rmse:0.06233
# [386]	validation-rmse:0.06232
# [387]	validation-rmse:0.06232
# [388]	validation-rmse:0.06232
# [389]	validation-rmse:0.06231
# [390]	validation-rmse:0.06231
# [391]	validation-rmse:0.06230
# [392]	validation-rmse:0.06230
# [393]	validation-rmse:0.06229
# [394]	validation-rmse:0.06229
# [395]	validation-rmse:0.06228
# [396]	validation-rmse:0.06229
# [397]	validation-rmse:0.06228
# [398]	validation-rmse:0.06228
# [399]	validation-rmse:0.06227
# [400]	validation-rmse:0.06227
# [401]	validation-rmse:0.06226
# [402]	validation-rmse:0.06225
# [403]	validation-rmse:0.06224
# [404]	validation-rmse:0.06222
# [405]	validation-rmse:0.06222
# [406]	validation-rmse:0.06221
# [407]	validation-rmse:0.06221
# [408]	validation-rmse:0.06219
# [409]	validation-rmse:0.06219
# [410]	validation-rmse:0.06218
# [411]	validation-rmse:0.06217
# [412]	validation-rmse:0.06217
# [413]	validation-rmse:0.06215
# [414]	validation-rmse:0.06214
# [415]	validation-rmse:0.06214
# [416]	validation-rmse:0.06213
# [417]	validation-rmse:0.06213
# [418]	validation-rmse:0.06213
# [419]	validation-rmse:0.06212
# [420]	validation-rmse:0.06212
# [421]	validation-rmse:0.06212
# [422]	validation-rmse:0.06211
# [423]	validation-rmse:0.06210
# [424]	validation-rmse:0.06210
# [425]	validation-rmse:0.06209
# [426]	validation-rmse:0.06209
# [427]	validation-rmse:0.06209
# [428]	validation-rmse:0.06208
# [429]	validation-rmse:0.06208
# [430]	validation-rmse:0.06207
# [431]	validation-rmse:0.06207
# [432]	validation-rmse:0.06207
# [433]	validation-rmse:0.06207
# [434]	validation-rmse:0.06206
# [435]	validation-rmse:0.06206
# [436]	validation-rmse:0.06206
# [437]	validation-rmse:0.06206
# [438]	validation-rmse:0.06206
# [439]	validation-rmse:0.06205
# [440]	validation-rmse:0.06205
# [441]	validation-rmse:0.06205
# [442]	validation-rmse:0.06204
# [443]	validation-rmse:0.06204
# [444]	validation-rmse:0.06204
# [445]	validation-rmse:0.06204
# [446]	validation-rmse:0.06203
# [447]	validation-rmse:0.06203
# [448]	validation-rmse:0.06203
# [449]	validation-rmse:0.06203
# [450]	validation-rmse:0.06203
# [451]	validation-rmse:0.06202
# [452]	validation-rmse:0.06202
# [453]	validation-rmse:0.06201
# [454]	validation-rmse:0.06201
# [455]	validation-rmse:0.06201
# [456]	validation-rmse:0.06201
# [457]	validation-rmse:0.06201
# [458]	validation-rmse:0.06200
# [459]	validation-rmse:0.06200
# [460]	validation-rmse:0.06200
# [461]	validation-rmse:0.06200
# [462]	validation-rmse:0.06200
# [463]	validation-rmse:0.06200
# [464]	validation-rmse:0.06199
# [465]	validation-rmse:0.06199
# [466]	validation-rmse:0.06199
# [467]	validation-rmse:0.06199
# [468]	validation-rmse:0.06199
# [469]	validation-rmse:0.06198
# [470]	validation-rmse:0.06198
# [471]	validation-rmse:0.06198
# [472]	validation-rmse:0.06198
# [473]	validation-rmse:0.06198
# [474]	validation-rmse:0.06197
# [475]	validation-rmse:0.06197
# [476]	validation-rmse:0.06197
# [477]	validation-rmse:0.06197
# [478]	validation-rmse:0.06197
# [479]	validation-rmse:0.06196
# [480]	validation-rmse:0.06196
# [481]	validation-rmse:0.06196
# [482]	validation-rmse:0.06196
# [483]	validation-rmse:0.06196
# [484]	validation-rmse:0.06195
# [485]	validation-rmse:0.06195
# [486]	validation-rmse:0.06195
# [487]	validation-rmse:0.06195
# [488]	validation-rmse:0.06194
# [489]	validation-rmse:0.06194
# [490]	validation-rmse:0.06194
# [491]	validation-rmse:0.06194
# [492]	validation-rmse:0.06194
# [493]	validation-rmse:0.06194
# [494]	validation-rmse:0.06194
# [495]	validation-rmse:0.06194
# [496]	validation-rmse:0.06194
# [497]	validation-rmse:0.06194
# [498]	validation-rmse:0.06194
# [499]	validation-rmse:0.06194
# [500]	validation-rmse:0.06194
# [501]	validation-rmse:0.06194
# [502]	validation-rmse:0.06194
# [503]	validation-rmse:0.06194
# [504]	validation-rmse:0.06194
# [505]	validation-rmse:0.06194
# [506]	validation-rmse:0.06194
# [507]	validation-rmse:0.06194
# [508]	validation-rmse:0.06194
# [509]	validation-rmse:0.06194
# [510]	validation-rmse:0.06194
# [511]	validation-rmse:0.06194
# [512]	validation-rmse:0.06194
# [513]	validation-rmse:0.06194
# [514]	validation-rmse:0.06194
# [515]	validation-rmse:0.06194
# [516]	validation-rmse:0.06194
# [517]	validation-rmse:0.06194
# [518]	validation-rmse:0.06194
# [519]	validation-rmse:0.06194
# [520]	validation-rmse:0.06194
# [521]	validation-rmse:0.06194
# [522]	validation-rmse:0.06194
# [523]	validation-rmse:0.06194
# [524]	validation-rmse:0.06194
# [525]	validation-rmse:0.06194
# [526]	validation-rmse:0.06194
# [527]	validation-rmse:0.06194
# [528]	validation-rmse:0.06194
# [529]	validation-rmse:0.06194
# [530]	validation-rmse:0.06194
# [531]	validation-rmse:0.06194
# [532]	validation-rmse:0.06194
# [533]	validation-rmse:0.06194
# [534]	validation-rmse:0.06194
# [535]	validation-rmse:0.06194
# [536]	validation-rmse:0.06194
# [537]	validation-rmse:0.06194
# [538]	validation-rmse:0.06194
# [539]	validation-rmse:0.06194
# [540]	validation-rmse:0.06194
